# %%
#loading the packages according to requirements
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns    
import warnings
warnings.filterwarnings('ignore')

# %%
dfa = pd.read_csv('heart attack.xls')

# %%
#Importing the data set  and displaying the data 
dfa = pd.read_csv('heart attack.xls')
dfa
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
#displaying the top 5 data 
dfa.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
#displaying last 5 data 
dfa.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
#changing the name of the columns 
colms = {'cp':'Chest Pain Type (CP)',
          'trestbps':'Resting Blood Pressure (trestbps)',
          'chol':'Serum Cholestoral (chol) mg/dl',
          'fbs':  'Fasting Blood Sugar (fbs) > 120 mg/dl',
          'restecg': 'Resting Electrocardiographic Results (restecg)',
          'thalach' : 'Maximum Heart Rate Achieved (thalach)',
          'exang': 'Exercise Induced Angina (exang)',
          'oldpeak' : 'ST depression (oldpeak)' ,
          'slope' : 'Slope of the ST Segment (slope)',
          'ca' : 'Number of Major Vessels (ca)',
          'thal' : 'Thal'}
dfa.rename(columns = colms, inplace = True)
dfa.head()
# Out:
#    age  sex  Chest Pain Type (CP)  Resting Blood Pressure (trestbps)  \
# 0   52    1                     0                                125
# 1   53    1                     0                                140
# 2   70    1                     0                                145
# 3   61    1                     0                                148
# 4   62    0                     0                                138
#
#    Serum Cholestoral (chol) mg/dl  Fasting Blood Sugar (fbs) > 120 mg/dl  \
# 0                             212                                      0
# 1                             203                                      1
# 2                             174                                      0
# 3                             203                                      0
# 4                             294                                      1
#
#    Resting Electrocardiographic Results (restecg)  \
# 0                                               1
# ...

# %%
# Explotary Data Analysis(EDA)
#displaying the data to know the datatype and null vallue in the dataset 
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   age                                             1025 non-null   int64
#  1   sex                                             1025 non-null   int64
#  2   Chest Pain Type (CP)                            1025 non-null   int64
#  3   Resting Blood Pressure (trestbps)               1025 non-null   int64
#  4   Serum Cholestoral (chol) mg/dl                  1025 non-null   int64
#  5   Fasting Blood Sugar (fbs) > 120 mg/dl           1025 non-null   int64
#  6   Resting Electrocardiographic Results (restecg)  1025 non-null   int64
#  7   Maximum Heart Rate Achieved (thalach)           1025 non-null   int64
#  8   Exercise Induced Angina (exang)                 1025 non-null   int64
# ...

# %%
#finding the total number of null value in data set 
dfa.isnull().sum()
# Out:
# age                                               0
# sex                                               0
# Chest Pain Type (CP)                              0
# Resting Blood Pressure (trestbps)                 0
# Serum Cholestoral (chol) mg/dl                    0
# Fasting Blood Sugar (fbs) > 120 mg/dl             0
# Resting Electrocardiographic Results (restecg)    0
# Maximum Heart Rate Achieved (thalach)             0
# Exercise Induced Angina (exang)                   0
# ST depression (oldpeak)                           0
# Slope of the ST Segment (slope)                   0
# Number of Major Vessels (ca)                      0
# Thal                                              0
# target                                            0
# dtype: int64

# %%
dfa.describe().transpose()
# Out:
#                                                  count        mean        std  \
# age                                             1025.0   54.434146   9.072290
# sex                                             1025.0    0.695610   0.460373
# Chest Pain Type (CP)                            1025.0    0.942439   1.029641
# Resting Blood Pressure (trestbps)               1025.0  131.611707  17.516718
# Serum Cholestoral (chol) mg/dl                  1025.0  246.000000  51.592510
# Fasting Blood Sugar (fbs) > 120 mg/dl           1025.0    0.149268   0.356527
# Resting Electrocardiographic Results (restecg)  1025.0    0.529756   0.527878
# Maximum Heart Rate Achieved (thalach)           1025.0  149.114146  23.005724
# Exercise Induced Angina (exang)                 1025.0    0.336585   0.472772
# ST depression (oldpeak)                         1025.0    1.071512   1.175053
# Slope of the ST Segment (slope)                 1025.0    1.385366   0.617755
# ...

# %%
sns.pairplot(dfa, hue="target", size=3, diag_kind="kde")

# %%
##displaying the data through hisplot (histogram)
sns.histplot(dfa['ST depression (oldpeak)'],kde = True)
plt.show()

# %%
##Displaying the data set through box plot 
sns.boxplot(x='ST depression (oldpeak)',  data= dfa)
plt.show()

# %%
#Removing the Outliers through IQR(Inter Qurtile Range) process 
q1 = dfa['ST depression (oldpeak)'].quantile(.25)
q3= dfa['ST depression (oldpeak)'].quantile(.75)
iqr = q3 - q1
mea = np.mean(dfa['ST depression (oldpeak)'])
sd = np.std(dfa['ST depression (oldpeak)'])

# %%
mid_range = q1 - (1.5 * iqr)
max_range = q3 + (1.5 * iqr)
mid_range , max_range
# Out:
# (-2.7, 4.5)

# %%
  dfaa = dfa[(dfa['ST depression (oldpeak)'] <= max_range)]

# %%
sns.boxplot(x='ST depression (oldpeak)', data = dfaa)
plt.show()

# %%
##Removing Outlers on Resting Blood Pressure 
##displaying the data through hisplot (histogram)
sns.histplot(dfa['Resting Blood Pressure (trestbps)'],kde = True)
plt.show()

# %%
##Displaying the data set through box plot 
sns.boxplot(x='Resting Blood Pressure (trestbps)',  data= dfa)
plt.show()

# %%
#removing the outliers from Resting Blood pressure columns 
# Q1 = first quartile range , Q3 = third quartile range , IQR = Inter Quartile Range 
Q1 = dfa['Resting Blood Pressure (trestbps)'].quantile(.25)
Q3 = dfa['Resting Blood Pressure (trestbps)'].quantile(.75)
IQR = Q3 - Q1

# %%
min_range = Q1 - (1.5 * IQR)
max_range = Q3 + (1.5 *IQR)
min_range , max_range
# Out:
# (90.0, 170.0)

# %%
## using IQR max range to eliminate the outliers
dfa = dfa[(dfa['Resting Blood Pressure (trestbps)'] <= max_range)]

# %%
#After REmoving the outliers of Resting Blood sugar 
sns.boxplot(x = 'Resting Blood Pressure (trestbps)', data = dfa)
plt.show()

# %%
##Removing Outlers on Serum Cholestoral (chol) mg/dl 
##displaying the data through hisplot (histogram)
sns.histplot(dfa['Serum Cholestoral (chol) mg/dl'],kde = True)
plt.show()

# %%
##Displaying the data set through box plot 
sns.boxplot(x='Serum Cholestoral (chol) mg/dl',  data= dfa)
plt.show()

# %%
#removing the outliers from Resting Blood pressure columns 
# Q1 = first quartile range , Q3 = third quartile range , IQR = Inter Quartile Range 
Q1 = dfa['Serum Cholestoral (chol) mg/dl'].quantile(.25)
Q3 = dfa['Serum Cholestoral (chol) mg/dl'].quantile(.75)
IQR = Q3 - Q1

# %%
min_range = Q1 - (1.5 * IQR)
max_range = Q3 + (1.5 *IQR)
min_range , max_range
# Out:
# (115.25, 369.25)

# %%
## using IQR max range to eliminate the outliers
dfa = dfa[(dfa['Serum Cholestoral (chol) mg/dl'] <= max_range)]

# %%
sns.boxplot(x='Serum Cholestoral (chol) mg/dl',  data= dfa)
plt.show()

# %%
##displaying the data through hisplot (histogram)
sns.histplot(dfa['Maximum Heart Rate Achieved (thalach)'],kde = True)
plt.show()

# %%
sns.boxplot(x='Serum Cholestoral (chol) mg/dl',  data= dfa)
plt.show()

# %%
#removing the outliers from Resting Blood pressure columns 
# Q1 = first quartile range , Q3 = third quartile range , IQR = Inter Quartile Range 
Q1 = dfa['Maximum Heart Rate Achieved (thalach)'].quantile(.25)
Q3 = dfa['Maximum Heart Rate Achieved (thalach)'].quantile(.75)
IQR = Q3 - Q1

# %%
min_range = Q1 - (1.5 * IQR)
max_range = Q3 + (1.5 *IQR)
min_range , max_range
# Out:
# (79.5, 219.5)

# %%
## using IQR max range to eliminate the outliers
dfa = dfa[(dfa['Maximum Heart Rate Achieved (thalach)'] <= max_range) & (dfa['Maximum Heart Rate Achieved (thalach)'] >= min_range)]

# %%
#After REmoving the outliers of Resting Blood sugar 
sns.boxplot(x = 'Maximum Heart Rate Achieved (thalach)', data = dfa)
plt.show()

# %%
##Final data after Removing Outliers
dfa
# Out:
#       age  sex  Chest Pain Type (CP)  Resting Blood Pressure (trestbps)  \
# 0      52    1                     0                                125
# 1      53    1                     0                                140
# 2      70    1                     0                                145
# 3      61    1                     0                                148
# 4      62    0                     0                                138
# ...   ...  ...                   ...                                ...
# 1020   59    1                     1                                140
# 1021   60    1                     0                                125
# 1022   47    1                     0                                110
# 1023   50    0                     0                                110
# 1024   54    1                     0                                120
#
#       Serum Cholestoral (chol) mg/dl  Fasting Blood Sugar (fbs) > 120 mg/dl  \
# ...

# %%
#showing the balance data 
# 1 = male 
# 0 = female 
age_rate = dfa['sex'].value_counts()
age_rate
# Out:
# sex
# 1    697
# 0    278
# Name: count, dtype: int64

# %%
tg = dfa['target'].value_counts()
tg
# Out:
# target
# 1    508
# 0    467
# Name: count, dtype: int64

# %%
plt.figure(figsize = (4,5))
sns.countplot(x=dfa['sex'],width = .8)
plt.legend(["male","Female"])
#plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.xlabel('Male and female')
plt.title("Male and female counts")
plt.ylabel('counts')
plt.show()

# %%
#finding the correlation ship 
dfa.corr()
# Out:
#                                                      age       sex  \
# age                                             1.000000 -0.076332
# sex                                            -0.076332  1.000000
# Chest Pain Type (CP)                           -0.068441 -0.081369
# Resting Blood Pressure (trestbps)               0.270180 -0.012844
# Serum Cholestoral (chol) mg/dl                  0.183581 -0.110063
# Fasting Blood Sugar (fbs) > 120 mg/dl           0.107088  0.050998
# Resting Electrocardiographic Results (restecg) -0.132916 -0.057993
# Maximum Heart Rate Achieved (thalach)          -0.401090 -0.051573
# Exercise Induced Angina (exang)                 0.084278  0.186243
# ST depression (oldpeak)                         0.206821  0.131935
# Slope of the ST Segment (slope)                -0.160079 -0.054727
# Number of Major Vessels (ca)                    0.284182  0.143392
# Thal                                            0.061928  0.222822
# ...

# %%
#showing correlation in heat map 
plt.figure(figsize = (10,9))
sns.heatmap(dfa.corr(), annot= True)
# Out:
# <Axes: >

# %%
# Create a pair plot using Seaborn
sns.pairplot(dfa[['age', 'Serum Cholestoral (chol) mg/dl', 'Thal', 'Resting Blood Pressure (trestbps)']])

# Add a title
plt.suptitle('Pair Plot of Variables')

# Show the plot
plt.show()

# %%
##max pluse  and resting BP
plt.figure(figsize = (14 ,6 ))
sns.violinplot(data = dfa , x = 'Thal', y = 'Resting Electrocardiographic Results (restecg)', hue ='target', palette = 'muted')
# Out:
# <Axes: xlabel='Thal', ylabel='Resting Electrocardiographic Results (restecg)'>

# %%
fig,ax = plt.subplots(figsize = (15,10))
sns.boxplot(data = dfa, x='age', y = 'Serum Cholestoral (chol) mg/dl', ax = ax, color = 'c')
# Out:
# <Axes: xlabel='age', ylabel='Serum Cholestoral (chol) mg/dl'>

# %%
##Spliting the data set into feature and target 
X = dfa.iloc[:,:-1]
y = dfa.iloc[:,-1:]

# %%
##Tranning the data set 
##Generating the Machine Learning Model 
##spiliting the data 
from sklearn.model_selection import train_test_split

X_train,X_test, y_train,y_test = train_test_split(X,y, test_size= .2,random_state = 34,stratify = y)

# %%
#importing the standardScaler 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
pd.DataFrame(X_train)
# Out:
#            0         1         2         3         4         5         6   \
# 0    1.195910  0.642685  1.986038  0.483817  0.908082  2.429538 -1.040439
# 1    0.207997  0.642685  1.017239 -0.033315  0.326901  2.429538 -1.040439
# 2    0.427533 -1.555973 -0.920359 -0.033315 -0.991935 -0.411601  0.896417
# 3   -0.779917  0.642685 -0.920359 -1.326145  0.751610 -0.411601 -1.040439
# 4   -0.779917  0.642685  1.017239 -0.033315  0.259841 -0.411601  0.896417
# ..        ...       ...       ...       ...       ...       ...       ...
# 775  0.866606 -1.555973 -0.920359  1.259515  0.058663 -0.411601  0.896417
# 776 -0.121308 -1.555973 -0.920359  0.483817 -0.164869 -0.411601 -1.040439
# 777 -0.999453 -1.555973 -0.920359  0.483817 -0.120163 -0.411601 -1.040439
# 778 -0.011540 -1.555973  0.048440  0.095968  1.042201  2.429538 -1.040439
# 779 -0.779917  0.642685 -0.920359 -1.196862 -0.835463 -0.411601  0.896417
#
#            7         8         9         10        11        12
# ...

# %%
pd.DataFrame(X_test)
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.983656  0.587220 -0.957481  0.807618 -1.222523 -0.365679 -0.941194
# 1    0.652564  0.587220 -0.957481 -0.207544  0.273749 -0.365679 -0.941194
# 2    0.542199  0.587220 -0.957481  2.837944  1.706799 -0.365679 -0.941194
# 3    0.100743 -1.702939 -0.957481 -0.004512 -0.843187 -0.365679  2.766540
# 4   -0.009621 -1.702939  1.018273 -1.222707 -0.653518 -0.365679  0.912673
# ..        ...       ...       ...       ...       ...       ...       ...
# 190 -1.333992  0.587220  2.006150  1.349038 -0.021290 -0.365679 -0.941194
# 191 -0.119986 -1.702939 -0.957481  0.130843  0.400195 -0.365679 -0.941194
# 192 -1.333992  0.587220 -0.957481  0.807618 -0.400627 -0.365679  0.912673
# 193 -1.113263 -1.702939  1.018273 -0.681287 -0.063439 -0.365679  0.912673
# 194  1.314749  0.587220 -0.957481  2.161169 -0.358479 -0.365679 -0.941194
#
#            7         8         9         10        11        12
# ...

# %%
## Importing the important libary 
from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC 
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import classification_report 
from sklearn.metrics import accuracy_score , confusion_matrix , log_loss , roc_auc_score , classification_report

# %%
#logistic regression 
llR = LogisticRegression()
##support Vector machine 
SSVM = SVC()
##Decision tree 
DDT = DecisionTreeClassifier()
##Kneighbors Classifer 
KNc = KNeighborsClassifier()

# %%
llR.fit(X_train,y_train)
SSVM.fit(X_train, y_train)
DDT.fit(X_train,y_train)
KNc.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
Score_llR = llR.score(X_test, y_test)
Score_DDT = DDT.score(X_test, y_test)
Score_KNc = KNc.score(X_test, y_test)
Score_SSVM = SSVM.score(X_test, y_test)
models = {'model':['Logistic_Regression','Support Vector Machine','Decision Tree Classifier', 'KNeighbors Classifier'], 'score':[Score_llR,Score_SSVM,Score_DDT,Score_KNc]}

# %%
##Logistic regression with regularlizations  
# Lasso (L1) Logistic Regression
lasso_log_reg = LogisticRegression(penalty='l1', solver='liblinear', max_iter = 200)
lasso_log_reg.fit(X_train, y_train)
y_pred_lasso = lasso_log_reg.predict(X_test)
print("Lasso (L1) Logistic Regression Classification Report:")
print(classification_report(y_test, y_pred_lasso))
# Out:
# Lasso (L1) Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.10      0.17        10
#            1       0.50      0.90      0.64        10
#
#     accuracy                           0.50        20
#    macro avg       0.50      0.50      0.40        20
# weighted avg       0.50      0.50      0.40        20

# %%
pd.DataFrame(models)
# Out:
#                       model     score
# 0       Logistic_Regression  0.887179
# 1    Support Vector Machine  0.943590
# 2  Decision Tree Classifier  0.979487
# 3     KNeighbors Classifier  0.861538

# %%
conf_mtx= []
for i , model_name in zip([llR,SSVM,DDT,KNc] , ['LogisticRegression', 'SupportVectorMachine', 'DecisionTreeClassifier', 'KNeighborsClassifier']):
    
    y_pred = i.predict(X_test)
    accuracy = confusion_matrix(y_test, y_pred)
    conf_mtx.append((model_name, accuracy))

conf_mtx_df = pd.DataFrame(conf_mtx, columns=['Model', 'Confusion Matrix'])

# %%
conf_mtx_df
# Out:
#                     Model      Confusion Matrix
# 0      LogisticRegression   [[77, 16], [6, 96]]
# 1    SupportVectorMachine    [[88, 5], [6, 96]]
# 2  DecisionTreeClassifier   [[90, 3], [1, 101]]
# 3    KNeighborsClassifier  [[79, 14], [13, 89]]

# %%
##Among the  alogrithm the more accuracy score is of Decision Tree Classifier 
##predictiong the model
pre_svm = SSVM.predict(X_test)

# %%
print(classification_report(y_test, pre_svm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94        93
#            1       0.95      0.94      0.95       102
#
#     accuracy                           0.94       195
#    macro avg       0.94      0.94      0.94       195
# weighted avg       0.94      0.94      0.94       195

# %%
#Finding best parameters for our SVC model
clf = DecisionTreeClassifier(random_state=0)
from sklearn.model_selection import GridSearchCV

# Define the hyperparameter grid
param_grid = {
    'max_depth': [3, 5, 7, 9],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}


Grid_decision = GridSearchCV(clf, param_grid, cv=10)
#grid_svc = GridSearchCV(SSVM, param_grid=param, scoring='accuracy', cv=10)

# %%
Grid_decision.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(random_state=0),
#              param_grid={'max_depth': [3, 5, 7, 9],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]})

# %%
#Best parameters for our svc model
Grid_decision.best_params_
# Out:
# {'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
#Let's run our DDT again with the best parameters.
dt = DecisionTreeClassifier(max_depth=9, min_samples_leaf=1, min_samples_split=2)
dt.fit(X_train, y_train)
Pred2_dt = dt.predict(X_test)
print(classification_report(y_test, Pred2_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        93
#            1       0.97      0.97      0.97       102
#
#     accuracy                           0.97       195
#    macro avg       0.97      0.97      0.97       195
# weighted avg       0.97      0.97      0.97       195

# %%
# Compute and plot the confusion matrix
cm = confusion_matrix(y_test, Pred2_dt)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Decision Tree Confusion Matrix")
plt.show()

# %%
##find the log loss of decision tree
y_pred_proba_ll = DDT.predict_proba(X_test)[:,1]
loss = log_loss(y_test, y_pred_proba_ll)
loss
print(f' The Log Loss for the Decision Tree model is {loss}')
# Out:
#  The Log Loss for the Decision Tree model is 0.739356992597275

# %%
y_pred_proba = DDT.predict_proba(X_test)[:,1]
auc_roc = roc_auc_score(y_test, y_pred_proba)
print(f' The Area under the ROC Curve for the Decison Tree model is is {auc_roc}')
# Out:
#  The Area under the ROC Curve for the Decison Tree model is is 0.9789690069576218

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# Predict probabilities
y_probs = DDT.predict_proba(X_test)[:, 1]

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_probs)

# Calculate AUC
auc = roc_auc_score(y_test, y_probs)
print(f'AUC: {auc:.2f}')

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {auc:.2f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# AUC: 0.98

# %%
## importing cross validation 
from sklearn.model_selection import cross_val_score 

from sklearn.model_selection import KFold

k = 10
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# Decison tree
DEcision_scr = cross_val_score(DDT,X, y, cv=kf)
print("Decision Tree models' average accuracy:", np.mean(DEcision_scr))
# Out:
# Decision Tree models' average accuracy: 1.0

# %%
##Finding accuracy Score 
acc = cross_val_score(estimator = DDT, X=X_train, y=y_train, cv=10)
acc
# Out:
# array([1.        , 1.        , 1.        , 0.97435897, 0.98717949,
#        0.92307692, 1.        , 1.        , 0.98717949, 0.97435897])

# %%
print(f'The cross validation scores are ::{acc}')
# Out:
# The cross validation scores are ::[1.         1.         1.         0.97435897 0.98717949 0.92307692
#  1.         1.         0.98717949 0.97435897]

# %%
print(f' The mean cross validation score is {acc.mean()}')
print(f' The standard deviation for the cross validation score is {acc.std()}')
# Out:
#  The mean cross validation score is 0.9846153846153847
#  The standard deviation for the cross validation score is 0.022790242095680986

# %%
##Implemeting the result in table Decision tree classifier
result = {
    'Result_name': ['Roc_accuracy', 'Accuracy', 'Accuracy_mean', 'Accuracy_standard'],
    'Result': [auc_roc, acc, acc.mean(), acc.std()]
}

pd.DataFrame(result, columns=['Result_name', 'Result'])
# Out:
#          Result_name                                             Result
# 0       Roc_accuracy                                           0.978969
# 1           Accuracy  [1.0, 1.0, 1.0, 0.9743589743589743, 0.98717948...
# 2      Accuracy_mean                                           0.984615
# 3  Accuracy_standard                                            0.02279
